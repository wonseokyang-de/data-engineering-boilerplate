# %%
from pyspark.sql import SparkSession

spark = (SparkSession.builder
        .appName('default')
        .config('spark.jars.packages', 'io.delta:delta-core_2.12:2.1.0')
        .config('spark.sql.extensions', 'io.delta.sql.DeltaSparkSessionExtension')
        .config('spark.sql.catalog.spark_catalog', 'org.apache.spark.sql.delta.catalog.DeltaCatalog')
        .getOrCreate()
    )
# Out:
# 24/09/07 15:56:03 WARN Utils: Your hostname, dead-line.local resolves to a loopback address: 127.0.0.1; using 192.168.219.187 instead (on interface en0)
# 24/09/07 15:56:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/opt/homebrew/anaconda3/envs/spark_3.5.1/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/dead_line/.ivy2/cache
# The jars for the packages stored in: /Users/dead_line/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-1d792870-799f-437f-83cb-65b43f204800;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.1.0 in central
# 	found io.delta#delta-storage;2.1.0 in central
# 	found org.antlr#antlr4-runtime;4.8 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# ...

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.219.187:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>default</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dataset_path = '../../dataset/'

# %%
procreate_raw_df = (spark.read.format('csv')
    .option('header', True)
    .option('encoding', 'EUC-KR')
    .load(dataset_path + 'korea-region-procreate-2023.csv')
)

# %%
procreate_raw_df.show()
# Out:
# +--------+----+------+---------+--------+
# |진료년도|시도|시군구|   연령군|분만건수|
# +--------+----+------+---------+--------+
# |    2023|서울|강남구|19세 이하|       0|
# |    2023|서울|강남구|  20~29세|     566|
# |    2023|서울|강남구|  30~39세|    6894|
# |    2023|서울|강남구|  40~49세|     802|
# |    2023|서울|강남구|50세 이상|       0|
# |    2023|서울|강동구|19세 이하|       0|
# |    2023|서울|강동구|  20~29세|     455|
# |    2023|서울|강동구|  30~39세|    3015|
# |    2023|서울|강동구|  40~49세|     271|
# |    2023|서울|강동구|50세 이상|       0|
# |    2023|서울|강서구|19세 이하|       0|
# |    2023|서울|강서구|  20~29세|     408|
# |    2023|서울|강서구|  30~39세|    3345|
# |    2023|서울|강서구|  40~49세|     303|
# |    2023|서울|강서구|50세 이상|       0|
# |    2023|서울|관악구|19세 이하|       0|
# |    2023|서울|관악구|  20~29세|      84|
# |    2023|서울|관악구|  30~39세|     494|
# |    2023|서울|관악구|  40~49세|      45|
# |    2023|서울|관악구|50세 이상|       0|
# +--------+----+------+---------+--------+
# only showing top 20 rows

# %%
procreate_raw_df.select(distinct('시도')

# %%
from pyspark.sql.functions import *

# %%
procreate_raw_df.select(distinct(col('시도')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 procreate_raw_df.select(distinct(col('시도')))
#
# NameError: name 'distinct' is not defined
# 24/09/07 17:31:00 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 988133 ms exceeds timeout 120000 ms
# 24/09/07 17:31:00 WARN SparkContext: Killing executors is not supported by current scheduler.
# 24/09/07 17:31:00 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# ...

# %%
procreate_raw_df.filter(col('시도')
